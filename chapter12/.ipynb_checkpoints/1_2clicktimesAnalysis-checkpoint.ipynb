# %%
# -*- coding:utf-8 -*-
### 第一部分 ###：数据探索分析——点击次数分析

# 目标：点击次数分析：统计分析原始数据用户浏览网页次数（以“真实IP”区分）的情况
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
from sqlalchemy import create_engine
import MySQLdb as msd
# 先自定义函数将表格写入数据库里，以备操作过程中有些数据要写入数据库
def savetosql(DF,tablename):
    import pandas as pd
    from sqlalchemy import create_engine
    yconnect = create_engine('mysql+mysqldb://root:@127.0.0.1:3306/jing?charset=utf8')  
    pd.io.sql.to_sql(DF,tablename, yconnect, schema='jing', if_exists='append')

# %%
# 读取数据库数据
engine = create_engine('mysql+pymysql://root:@127.0.0.1:3306/jing?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)


#-----* 1 *-----统计点击次数
counts1 = [i['realIP'].value_counts() for i in sql] # 分块统计各个IP的出现次数
counts1 = pd.concat(counts1).groupby(level=0).sum() # 合并统计结果，level=0表示按照index分组

counts1
# Out:
# 82033         2
# 95502         1
# 103182        1
# 116010        2
# 136206        1
# 140151        1
# 155761        1
# 159601        2
# 159758        1
# 213105        1
# 226318        2
# 235278        2
# 235790        2
# 270457        1
# 287601        2
# 358926        1
# 395385        2
# 418673        2
# 424206        3
# 430862        2
# 484209        1
# 496398        1
# 503676        1
# 540785        1
# 546996        1
# 606321        2
# 611448        8
# 614513        1
# 620302        1
# 629518        1
#              ..
# 4294016014    2
# 4294029180    9
# 4294054926    1
# 4294060347    2
# 4294086926    1
# 4294116791    1
# 4294186868    1
# 4294205040    4
# 4294247863    3
# 4294284558    7
# 4294341134    1
# 4294378935    3
# 4294444471    2
# 4294458682    3
# 4294481678    1
# 4294510007    3
# 4294510713    8
# 4294525553    1
# 4294549006    1
# 4294721082    3
# 4294721905    1
# 4294737166    1
# 4294786618    4
# 4294804343    1
# 4294807822    1
# 4294809358    2
# 4294811150    1
# 4294852154    3
# 4294865422    2
# 4294917690    1
# Name: realIP, Length: 230149, dtype: int64

# %%
counts1_ = DataFrame(counts1)
counts1_[1]=1 # 添加1列全为1
a = counts1_.groupby('realIP').sum()#统计各个“不同点击次数”分别出现的次数# 也可以使用counts1_['realIP'].value_counts()功能
a.columns=[u'用户数']
a.index.name = u'点击次数'
a[u'用户百分比'] = a[u'用户数']/a[u'用户数'].sum()*100
a[u'记录百分比'] = a[u'用户数']*a.index/counts1_['realIP'].sum()*100
a.sort_index(inplace = True)
b = a.iloc[:7,:]
c = b.T
c
# Out:
# 点击次数               1             2             3             4            5  \
# 用户数    132119.000000  44175.000000  17573.000000  10156.000000  5952.000000
# 用户百分比      57.405854     19.194087      7.635488      4.412793     2.586151
# 记录百分比      15.776345     10.549884      6.295182      4.850916     3.553645
#
# 点击次数             6            7
# 用户数    4132.000000  2632.000000
# 用户百分比     1.795359     1.143607
# 记录百分比     2.960416     2.200012

# %%
#-----* 2 *-----统计1~7次数及7次以上的
c.insert(0,u'总计',[a[u'用户数'].sum(),100,100])
c[u'7次及以上'] = c.iloc[:,0]- c.iloc[:,1:].sum(1)
c
# Out:
# 点击次数       总计              1             2             3             4  \
# 用户数    230149  132119.000000  44175.000000  17573.000000  10156.000000
# 用户百分比     100      57.405854     19.194087      7.635488      4.412793
# 记录百分比     100      15.776345     10.549884      6.295182      4.850916
#
# 点击次数             5            6            7         7次及以上
# 用户数    5952.000000  4132.000000  2632.000000  13410.000000
# 用户百分比     2.586151     1.795359     1.143607      5.826660
# 记录百分比     3.553645     2.960416     2.200012     53.813601

# %%
# 转置表格，并将所有输出保留两位小数
d = c.T
format = lambda x: '%.2f' % x  # 也可以使用d.round(4)
d = d.applymap(format)
d
# Out:
#              用户数   用户百分比   记录百分比
# 点击次数
# 总计     230149.00  100.00  100.00
# 1      132119.00   57.41   15.78
# 2       44175.00   19.19   10.55
# 3       17573.00    7.64    6.30
# 4       10156.00    4.41    4.85
# 5        5952.00    2.59    3.55
# 6        4132.00    1.80    2.96
# 7        2632.00    1.14    2.20
# 7次及以上   13410.00    5.83   53.81

# %%
# 分析浏览次数7次以上的数据
times = counts1_.index[7:]
bins = [7,100,1000,50000]
cats = pd.cut(times,bins,right=True,labels=['8~100','101~1000','1000以上'])
e = cats.value_counts()
e = DataFrame(e, columns =[u'频数'])
e.index.name = u'点击次数'

# %%
e[u'用户数'] = np.nan
e.ix[u'8~100',u'用户数'] = a.loc[8:100,:][u'用户数'].sum()
e.ix['101~1000',u'用户数'] = a.loc[101:1000,:][u'用户数'].sum()
e.ix['1000以上',u'用户数'] = a.loc[1001:,:][u'用户数'].sum()
e.sort_values(by=u'用户数',ascending=False,inplace = True)
e
# Out:
#           频数      用户数
# 点击次数
# 8~100      0  12952.0
# 101~1000   0    439.0
# 1000以上     0     19.0

# %%
#-----* 3 *-----对浏览一次的用户行为进行分析

# 读取数据库数据
engine = create_engine('mysql+pymysql://root:@127.0.0.1:3306/jing?charset=utf8')
sql = pd.read_sql('all_gzdata', engine, chunksize = 10000)

# %%
# 获取浏览一次的所有数据
f = counts1_[counts1_['realIP']==1]
del f[1]
f.columns = [u'点击次数']
f.index.name = 'realIP'
# g = [pd.merge(f,i[['fullURLId','fullURL','realIP']],right_on = 'realIP',left_index=True,how ='left') for i in sql]
g = [i[['fullURLId','fullURL','realIP']] for i in sql]
g = pd.concat(g)
h = pd.merge(f,g,right_on = 'realIP',left_index=True,how ='left')
h
# Out:
#       点击次数 fullURLId                                            fullURL  \
# 5978     1    101003    http://www.lawtime.cn/ask/question_7882607.html
# 0        1    101003    http://www.lawtime.cn/ask/question_7174864.html
# 1083     1    101003    http://www.lawtime.cn/ask/question_8246285.html
# 6727     1    107001  http://www.lawtime.cn/info/gongsi/slbgfgs/2011...
# 1801     1    101003    http://www.lawtime.cn/ask/question_5951952.html
# 8191     1    101003    http://www.lawtime.cn/ask/question_1909224.html
# 2222     1    101003    http://www.lawtime.cn/ask/question_1586269.html
# 542      1    101003    http://www.lawtime.cn/ask/question_2077376.html
# 8043     1    101003    http://www.lawtime.cn/ask/question_6086745.html
# 9071     1    101003    http://www.lawtime.cn/ask/question_3377950.html
# 39       1    101003    http://www.lawtime.cn/ask/question_3899360.html
# 8472     1   1999001           http://www.lawtime.cn/ask/exp/13445.html
# 6957     1    101003     http://www.lawtime.cn/ask/question_890601.html
# 5520     1    107001  http://www.lawtime.cn/info/maoyi/guojimaoyicha...
# 6447     1    101003    http://www.lawtime.cn/ask/question_6659844.html
# 4609     1    101003    http://www.lawtime.cn/ask/question_6358337.html
# 8409     1    101003     http://www.lawtime.cn/ask/question_536408.html
# 1564     1    107001  http://www.lawtime.cn/info/hetongshencha/baomi...
# ...          ...
# 1046  4293229582
# 3401  4293230350
# 8702  4293236238
# 302   4293431566
# 1531  4293468535
# 9710  4293495869
# 5810  4293497102
# 3803  4293556238
# 5557  4293678200
# 4706  4293687310
# 5477  4293793652
# 2259  4293920183
# 9739  4293949966
# 9662  4293985719
# 9271  4294012942
# 4479  4294015502
# 2023  4294054926
# 5437  4294086926
# 2085  4294116791
# 2771  4294186868
# 3661  4294341134
# 4524  4294481678
# 121   4294525553
# 6332  4294549006
# 8189  4294721905
# 1018  4294737166
# 1677  4294804343
# 4035  4294807822
# 9108  4294811150
# 2631  4294917690
#
# [132119 rows x 4 columns]

# %%
# 浏览一次的用户的网页类型ID分析
i = h['fullURLId'].value_counts()
i = DataFrame(i)
i.rename(columns={'fullURLId':u'个数'},inplace=True)
i.index.name = u'网页类型ID'
i[u'百分比'] = i[u'个数']/i[u'个数'].sum()*100
i
# Out:
#              个数        百分比
# 网页类型ID
# 101003   102560  77.626988
# 107001    19443  14.716279
# 1999001    9381   7.100417
# 301001      515   0.389800
# 102001       70   0.052983
# 103003       45   0.034060
# 101002       33   0.024977
# 101001       28   0.021193
# 106001       13   0.009840
# 102002       13   0.009840
# 101009        4   0.003028
# 101007        3   0.002271
# 101004        3   0.002271
# 101008        2   0.001514
# 102003        2   0.001514
# 101006        1   0.000757
# 102004        1   0.000757
# 102006        1   0.000757
# 101005        1   0.000757

# %%
j = i[i[u'个数']>100]
j
# Out:
#              个数        百分比
# 网页类型ID
# 101003   102560  77.626988
# 107001    19443  14.716279
# 1999001    9381   7.100417
# 301001      515   0.389800

# %%
j.loc[u'其他',u'个数'] = i[i[u'个数']<=100][u'个数'].sum()
j.loc[u'其他',u'百分比'] = 100-i[i[u'个数']>100][u'百分比'].sum()
j# 浏览一次的用户中浏览的网页类型ID
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                个数        百分比
# 网页类型ID
# 101003   102560.0  77.626988
# 107001    19443.0  14.716279
# 1999001    9381.0   7.100417
# 301001      515.0   0.389800
# 其他          220.0   0.166517

# %%
#　点击1次用户浏览网页统计(点击数大于100次的)
k = DataFrame(h['fullURL'].value_counts())
k.index.name = u'网址'
k.columns = [u'点击数']
m = k[k[u'点击数'] > 100]
m.loc[u'其他',u'点击数'] = k[k[u'点击数']<=100][u'点击数'].sum()
m[u'百分比'] = m[u'点击数']/k[u'点击数'].sum()
m
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                          点击数       百分比
# 网址
# http://www.lawtime.cn/info/shuifa/slb/201211197...    1013.0  0.007667
# http://www.lawtime.cn/info/hunyin/lhlawlhxy/201...     501.0  0.003792
# http://www.lawtime.cn/ask/question_925675.html         423.0  0.003202
# http://www.lawtime.cn/info/shuifa/slb/201211197...     367.0  0.002778
# http://www.lawtime.cn/ask/exp/13655.html               301.0  0.002278
# http://www.lawtime.cn/ask/exp/8495.html                241.0  0.001824
# http://www.lawtime.cn/ask/exp/13445.html               199.0  0.001506
# http://www.lawtime.cn/guangzhou                        177.0  0.001340
# http://www.lawtime.cn/ask/exp/17357.html               171.0  0.001294
# http://www.lawtime.cn/ask/exp/13943.html               117.0  0.000886
# http://www.lawtime.cn/citylist.php                     117.0  0.000886
# http://www.lawtime.cn/info/shuifa/grsds/2014103...     111.0  0.000840
# http://www.lawtime.cn/ask/question_7148707.html        104.0  0.000787
# 其他                                                  128277.0  0.970920
